# %%
import pandas as pd

# %%
df = pd.read_csv('processed.csv')

# %%
df.head()
# Out:
#       chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 0  1285560920                 1               -1                   NaN
# 1  1285560920                 1               -1                   NaN
# 2  1285560920                 1               -1                   NaN
# 3  1285560920                 1               -1                   NaN
# 4   413665976                 2        413665976              Михайлов
#
#   active_user_nickname  active_user_id   timestamp  message_type  \
# 0                 Катя            8380  1573827287             0
# 1                 Катя            8380  1573827428             0
# 2                 Катя            8380  1573827477             0
# 3                 Катя            8380  1573827662             0
# 4                 Катя            8380  1588349482             2
#
#    symbols_count  picture_count  emoji_count  link_count  video_count  \
# 0              0              0            1           0            0
# ...

# %%
df.shape
# Out:
# (140593, 15)

# %%
df[df['timestamp'] == 1660913117]
# Out:
#           chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 140222  765513831                 1               -1                   NaN
#
#        active_user_nickname  active_user_id   timestamp  message_type  \
# 140222                 Катя               1  1660913117             0
#
#         symbols_count  picture_count  emoji_count  link_count  video_count  \
# 140222            243              6            6           6            0
#
#         seconds_count  is_forwarded
# 140222              0          True

# %%
df[df['timestamp'] == 1689709662]
# Out:
#           chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 100633  648530004                 2        648530004             Витовочка
#
#        active_user_nickname  active_user_id   timestamp  message_type  \
# 100633            Витовочка       648530004  1689709662             0
#
#         symbols_count  picture_count  emoji_count  link_count  video_count  \
# 100633              0              0            0           0            0
#
#         seconds_count  is_forwarded
# 100633              0          True

# %%
df[df['timestamp'] == 1681841300] # видеозвонок
# Out:
#          chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 87596  648530004                 2        648530004             Витовочка
#
#       active_user_nickname  active_user_id   timestamp  message_type  \
# 87596                 Катя               1  1681841300             4
#
#        symbols_count  picture_count  emoji_count  link_count  video_count  \
# 87596              0              0            0           0            0
#
#        seconds_count  is_forwarded
# 87596             20         False

# %%
df[df['timestamp'] == 1682107548] # видео
# Out:
#          chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 88689  648530004                 2        648530004             Витовочка
#
#       active_user_nickname  active_user_id   timestamp  message_type  \
# 88689            Витовочка       648530004  1682107548             1
#
#        symbols_count  picture_count  emoji_count  link_count  video_count  \
# 88689              0              0            0           0            0
#
#        seconds_count  is_forwarded
# 88689             16         False

# %%
df[df['timestamp'] == 1683203434] # видео
# Out:
#          chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 90593  648530004                 2        648530004             Витовочка
#
#       active_user_nickname  active_user_id   timestamp  message_type  \
# 90593            Витовочка       648530004  1683203434             0
#
#        symbols_count  picture_count  emoji_count  link_count  video_count  \
# 90593              0              7            0           0            2
#
#        seconds_count  is_forwarded
# 90593             28         False

# %%
df[df['timestamp'] == 1682112964]
# Out:
#          chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 88697  648530004                 2        648530004             Витовочка
#
#       active_user_nickname  active_user_id   timestamp  message_type  \
# 88697            Витовочка       648530004  1682112964             0
#
#        symbols_count  picture_count  emoji_count  link_count  video_count  \
# 88697             30              0            1           0            0
#
#        seconds_count  is_forwarded
# 88697              0         False

# %%
df['message_type'].value_counts()
# Out:
# 0    130912
# 1      5537
# 2      3780
# 4       364
# Name: message_type, dtype: int64

# %%
df[df['video_count'] > 0]
# Out:
#           chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 169     784296870                 2        784296870                Marina
# 1579    573434155                 2        573434155           Катя-сырник
# 1997    212215704                 2        212215704                  Анна
# 2011    212215704                 2        212215704                  Анна
# 2320    869630256                 2        869630256                Полина
# ...           ...               ...              ...                   ...
# 140295  765513831                 1               -1                   NaN
# 140300  765513831                 1               -1                   NaN
# 140301  765513831                 1               -1                   NaN
# 140319  765513831                 1               -1                   NaN
# 140518  765513831                 1               -1                   NaN
#
# ...

# %%
df[df['message_type'] == 0]
# Out:
#            chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 0       1285560920                 1               -1                   NaN
# 1       1285560920                 1               -1                   NaN
# 2       1285560920                 1               -1                   NaN
# 3       1285560920                 1               -1                   NaN
# 5        413665976                 2        413665976              Михайлов
# ...            ...               ...              ...                   ...
# 140224   765513831                 1               -1                   NaN
# 140225   765513831                 1               -1                   NaN
# 140226   765513831                 1               -1                   NaN
# 140227   765513831                 1               -1                   NaN
# 140228   765513831                 1               -1                   NaN
#
# ...

# %%
df[df['timestamp'] == 1681841504]
# Out:
#          chat_id  chat_users_count  partner_used_id partner_user_nickname  \
# 87340  648530004                 2        648530004             Витовочка
#
#       active_user_nickname  active_user_id   timestamp  message_type  \
# 87340                 Катя               1  1681841504             0
#
#        symbols_count  picture_count  emoji_count  link_count  video_count  \
# 87340             36              0            0           1            0
#
#        seconds_count  is_forwarded
# 87340              0         False
